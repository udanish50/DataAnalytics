# %%
import os
import torch
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
import plotly.graph_objects as go
from torch.utils.data import DataLoader

def minmax_scale(tensor):
    tensor_min = tensor.min()
    tensor_max = tensor.max()
    scaled_tensor = (tensor - tensor_min) / (tensor_max - tensor_min)
    return scaled_tensor, tensor_min, tensor_max

def inverse_minmax_scale(scaled_tensor, tensor_min, tensor_max):
    original_tensor = scaled_tensor * (tensor_max - tensor_min) + tensor_min
    return original_tensor
    
def smape(y_true, y_pred):
    return 100 * torch.mean(2 * torch.abs(y_true - y_pred) / (torch.abs(y_true) + torch.abs(y_pred))).item()

def rmse(y_true, y_pred):
    return torch.sqrt(torch.mean((y_true - y_pred) ** 2))
    
def mae(y_true, y_pred):
    return torch.mean(torch.abs(y_true - y_pred))


window_size = 24
horizon = 24
train_prop = 0.6
val_prop = 0.2

df1 = pd.read_csv('detached1.csv')
df2 = pd.read_csv('detached2.csv')
df1 = pd.read_csv('detached1.csv').drop(columns=['Datetime'])
df2 = pd.read_csv('detached2.csv').drop(columns=['Datetime'])

class SlidingWindowsDataset(torch.utils.data.Dataset):
    def __init__(self, data, window_size=24, horizon=24):
        self.data = data
        self.window_size = window_size
        self.horizon = horizon
        
        self.feature_mins = self.data.min(axis=0).values
        self.feature_maxs = self.data.max(axis=0).values
    
    def __len__(self):
        return len(self.data) - (self.window_size + self.horizon) + 1

    def __getitem__(self, idx):
        window = self.data[idx: idx + self.window_size + self.horizon]
        scaled_past_all_features = window[:self.window_size]
        future_energy = window[self.window_size:, -1:]
        
        #scaled_past_all_features = (past_all_features - self.feature_mins) / (self.feature_maxs - self.feature_mins)
        
        scaled_future_energy, energy_min, energy_max = minmax_scale(future_energy)

        return scaled_past_all_features, scaled_future_energy, (energy_min, energy_max)

import torch

df_dict = {
    'Detached_House_1': df1,
    'Detached_House_2':df2
}

train_datasets = {}
val_datasets = {}
test_datasets = {}

for dataset_name, dataset_df in df_dict.items():
    # Convert to tensor and perform the split
    data_tensor = torch.from_numpy(dataset_df.values).float()

    data_shape = data_tensor.shape[0]
    train_end = int(data_shape * train_prop)
    val_end = int(data_shape * (train_prop + val_prop))

    train_data = data_tensor[:train_end]
    val_data = data_tensor[train_end:val_end]
    test_data = data_tensor[val_end:]
    
    train_datasets[dataset_name] = SlidingWindowsDataset(train_data, window_size, horizon)
    val_datasets[dataset_name] = SlidingWindowsDataset(val_data, window_size, horizon)
    test_datasets[dataset_name] = SlidingWindowsDataset(test_data, window_size, horizon)

for dwelling_type, dataset in train_datasets.items():
    item = dataset[0]  # This gets the first item in the dataset
    past_features, future_energy, (energy_min, energy_max) = item
    
    print(f"Data for {dwelling_type}:")
    print("Past Features:")
    print(past_features)
    print("Future Energy:")
    print(future_energy)
    print("Energy Min:", energy_min.item())
    print("Energy Max:", energy_max.item())
    print("\n" + "="*50 + "\n")
# Out:
# Data for Detached_House_1:
# Past Features:
# tensor([[2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.8000e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.0000e+00, 1.9600e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.0000e+00, 1.8000e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 3.0000e+00, 1.9000e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 4.0000e+00, 1.7900e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 5.0000e+00, 1.8300e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 6.0000e+00, 1.8400e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 7.0000e+00, 1.9800e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 8.0000e+00, 2.1100e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 9.0000e+00, 2.1400e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.0000e+01, 2.0200e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.1000e+01, 2.0800e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.2000e+01, 1.8900e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.3000e+01, 2.0200e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.4000e+01, 1.8600e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.5000e+01, 1.9200e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.6000e+01, 2.2600e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.7000e+01, 2.0400e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.8000e+01, 2.5500e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.9000e+01, 2.5800e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.0000e+01, 2.4400e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.1000e+01, 2.4400e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.2000e+01, 1.9900e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.3000e+01, 1.9000e+03]])
# Future Energy:
# tensor([[0.1020],
#         [0.0918],
#         [0.1735],
#         [0.1020],
#         [0.0714],
#         [0.0408],
#         [0.0000],
#         [0.0918],
#         [0.1633],
#         [0.3469],
#         [1.0000],
#         [0.2959],
#         [0.4694],
#         [0.2143],
#         [0.4184],
#         [0.1837],
#         [0.0918],
#         [0.1020],
#         [0.6939],
#         [0.8571],
#         [0.5918],
#         [0.3163],
#         [0.0102],
#         [0.0816]])
# Energy Min: 1860.0
# Energy Max: 2840.0
#
# ==================================================
#
# Data for Detached_House_2:
# Past Features:
# tensor([[2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 0.0000e+00, 5.4000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.0000e+00, 5.1000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.0000e+00, 5.9000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 3.0000e+00, 4.9000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 4.0000e+00, 5.0000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 5.0000e+00, 4.8000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 6.0000e+00, 6.9000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 7.0000e+00, 5.5000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 8.0000e+00, 6.1000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 9.0000e+00, 8.7000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.0000e+01, 7.8000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.1000e+01, 8.2000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.2000e+01, 8.2000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.3000e+01, 6.3000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.4000e+01, 5.3000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.5000e+01, 5.6000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.6000e+01, 7.5000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.7000e+01, 7.5000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.8000e+01, 7.8000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 1.9000e+01, 1.1000e+03],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.0000e+01, 7.0000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.1000e+01, 7.6000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.2000e+01, 7.7000e+02],
#         [2.0000e+00, 6.0000e+01, 1.0000e+00, 0.0000e+00, 2.3000e+01, 6.0000e+02]])
# Future Energy:
# tensor([[0.0067],
#         [0.0201],
#         [0.0403],
#         [0.0134],
#         [0.0000],
#         [0.0201],
#         [0.8993],
#         [0.4430],
#         [0.4564],
#         [0.3221],
#         [0.3691],
#         [0.1477],
#         [0.1074],
#         [0.2483],
#         [0.0738],
#         [0.0537],
#         [0.2483],
#         [1.0000],
#         [0.1946],
#         [0.3221],
#         [0.1611],
#         [0.2685],
#         [0.1812],
#         [0.0470]])
# Energy Min: 450.0
# Energy Max: 1940.0
#
# ==================================================

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, dropout=0.8)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out)
        return out

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

if device.type == 'cuda':
    print("Training will be performed on GPU")
else:
    print("Training will be performed on CPU")

learning_rate = 0.001

def train(model, data_loader, optimizer, loss_fn):
    model.train()
    losses = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    for inputs, scaled_targets, future_energy_min_max in data_loader:
        inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
        #print("Scaled Targets:", scaled_targets[0].cpu().numpy())  # Print the first scaled target
        targets_min, targets_max = future_energy_min_max
        targets_min, targets_max = targets_min.to(device), targets_max.to(device)
        #print("Min for targets:", targets_min[0].item())   # Print min value used for scaling for the first target
        #print("Max for targets:", targets_max[0].item())   # Print max value used for scaling for the first target

        outputs = model(inputs)
        #print(outputs.shape)
        loss = loss_fn(outputs, scaled_targets)
        losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)
        optimizer.step()

        targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
        #print("Inverse Scaled Targets:", targets[0].cpu().numpy())  # Print the first inverse scaled target
        outputs = inverse_minmax_scale(outputs, targets_min, targets_max)
        #print("Inverse Scaled Outputs:", outputs[0].detach().cpu().numpy())    # Print the first inverse scaled output

        metrics['MAE'].append(mae(outputs, targets).item())
        metrics['RMSE'].append(rmse(outputs, targets).item())
        metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}

def evaluate(model, data_loader, loss_fn):
    model.eval()
    losses = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    with torch.no_grad():
        for inputs, scaled_targets, future_energy_min_max in data_loader:
            inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
            targets_min, targets_max = future_energy_min_max
            targets_min, targets_max = targets_min.to(device), targets_max.to(device)

            outputs = model(inputs)
            loss = loss_fn(outputs, scaled_targets)
            losses.append(loss.item())

            targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
            outputs = inverse_minmax_scale(outputs, targets_min, targets_max)

            metrics['MAE'].append(mae(outputs, targets).item())
            metrics['RMSE'].append(rmse(outputs, targets).item())
            metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}
    
model = LSTM(input_size=6, hidden_size=32, output_size=1).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=1e-7)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)
loss_fn = nn.L1Loss()

def train_and_validate(datasets, num_epochs, patience, loss_fn):
    plots_dir = "./LSTM_MSE/"
    
    for dataset_name in datasets['train'].keys():
        print(f"Training for dataset: {dataset_name}")
        
        train_loader = DataLoader(datasets['train'][dataset_name], batch_size=1, shuffle=False)
        val_loader = DataLoader(datasets['val'][dataset_name], batch_size=1, shuffle=False)
        
        best_val_loss = np.inf
        epochs_no_improve = 0

        train_loss_history = []
        val_loss_history = []
        train_mae_history = []
        val_mae_history = []
        train_rmse_history = []
        val_rmse_history = []
        train_smape_history = []
        val_smape_history = []

        for epoch in range(num_epochs):
            train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn)
            val_loss, val_metrics = evaluate(model, val_loader, loss_fn)
            scheduler.step(val_loss)
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1

            if epochs_no_improve == patience:
                print(f"Early stopping triggered after {epoch + 1} epochs for dataset {dataset_name}.")
                break

            train_loss_history.append(train_loss)
            val_loss_history.append(val_loss)
            train_mae_history.append(train_metrics['MAE'])
            val_mae_history.append(val_metrics['MAE'])
            train_rmse_history.append(train_metrics['RMSE'])
            val_rmse_history.append(val_metrics['RMSE'])
            train_smape_history.append(train_metrics['SMAPE'])
            val_smape_history.append(val_metrics['SMAPE'])

            print(f"Epoch {epoch + 1}/{num_epochs} for dataset {dataset_name}")
            print(f"Train Loss: {train_loss:.2f}, Validation Loss: {val_loss:.2f}")
            print(f"Train MAE: {train_metrics['MAE']:.2f}, Validation MAE: {val_metrics['MAE']:.2f}")
            print(f"Train RMSE: {train_metrics['RMSE']:.2f}, Validation RMSE: {val_metrics['RMSE']:.2f}")
            print(f"Train SMAPE: {train_metrics['SMAPE']:.2f}, Validation SMAPE: {val_metrics['SMAPE']:.2f}")

        # Create plots and save them for each dataset
        def plot_metrics(history1, history2, title, ylabel, filename):
            fig = go.Figure()
            fig.add_trace(go.Scatter(y=history1, mode='lines', name='Train'))
            fig.add_trace(go.Scatter(y=history2, mode='lines', name='Validation'))
            fig.update_layout(title=title, xaxis_title='Epoch', yaxis_title=ylabel)
            fig.write_image(f"{plots_dir}/{dataset_name}_{filename}")

        plot_metrics(train_loss_history, val_loss_history, 'Loss vs Epoch', 'Loss', 'drop_loss_plot.png')
        plot_metrics(train_mae_history, val_mae_history, 'MAE vs Epoch', 'MAE', 'drop_mae_plot.png')
        plot_metrics(train_rmse_history, val_rmse_history, 'RMSE vs Epoch', 'RMSE', 'drop_rmse_plot.png')
        plot_metrics(train_smape_history, val_smape_history, 'SMAPE vs Epoch', 'SMAPE', 'drop_smape_plot.png')

        # Save the model for each dataset
        torch.save(model.state_dict(), f'./LSTM_MSE/LSTM_{loss_fn}_{dataset_name}.pth')

datasets = {
    'train': train_datasets,
    'val': val_datasets,
    'test': test_datasets
}



patience = 10
num_epochs = 500

train_and_validate(datasets, num_epochs, patience, loss_fn)
# Out:
# Training will be performed on GPU
# Training for dataset: Detached_House_1
# Epoch 1/500 for dataset Detached_House_1
# Train Loss: 0.30, Validation Loss: 0.31
# Train MAE: 381.82, Validation MAE: 686.80
# Train RMSE: 468.44, Validation RMSE: 792.35
# Train SMAPE: 24.57, Validation SMAPE: 29.73
# Epoch 2/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 308.98, Validation MAE: 684.20
# Train RMSE: 381.15, Validation RMSE: 785.03
# Train SMAPE: 19.26, Validation SMAPE: 29.64
# Epoch 3/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.93
# Train RMSE: 378.96, Validation RMSE: 784.55
# Train SMAPE: 19.20, Validation SMAPE: 29.63
# Epoch 4/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.89
# Train RMSE: 378.94, Validation RMSE: 784.53
# Train SMAPE: 19.20, Validation SMAPE: 29.63
# Epoch 5/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.87
# Train RMSE: 378.93, Validation RMSE: 784.54
# Train SMAPE: 19.20, Validation SMAPE: 29.63
# Epoch 6/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.86
# Train RMSE: 378.94, Validation RMSE: 784.55
# Train SMAPE: 19.20, Validation SMAPE: 29.63
# Epoch 7/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.83
# Train RMSE: 378.94, Validation RMSE: 784.50
# Train SMAPE: 19.20, Validation SMAPE: 29.63
# Epoch 8/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.82
# Train RMSE: 378.92, Validation RMSE: 784.50
# Train SMAPE: 19.20, Validation SMAPE: 29.63
# Epoch 9/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.81
# Train RMSE: 378.93, Validation RMSE: 784.51
# Train SMAPE: 19.20, Validation SMAPE: 29.62
# Epoch 10/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.81
# Train RMSE: 378.93, Validation RMSE: 784.51
# Train SMAPE: 19.20, Validation SMAPE: 29.62
# Epoch 11/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.80
# Train RMSE: 378.93, Validation RMSE: 784.51
# Train SMAPE: 19.20, Validation SMAPE: 29.62
# Epoch 12/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.80
# Train RMSE: 378.94, Validation RMSE: 784.51
# Train SMAPE: 19.20, Validation SMAPE: 29.62
# Epoch 00013: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 13/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 307.68, Validation MAE: 683.80
# Train RMSE: 378.94, Validation RMSE: 784.51
# Train SMAPE: 19.20, Validation SMAPE: 29.62
# Epoch 14/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 309.83, Validation MAE: 691.73
# Train RMSE: 378.27, Validation RMSE: 801.12
# Train SMAPE: 19.36, Validation SMAPE: 29.96
# Epoch 15/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 310.23, Validation MAE: 693.16
# Train RMSE: 380.56, Validation RMSE: 804.10
# Train SMAPE: 19.33, Validation SMAPE: 30.02
# Epoch 16/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 310.39, Validation MAE: 693.32
# Train RMSE: 380.88, Validation RMSE: 804.44
# Train SMAPE: 19.34, Validation SMAPE: 30.03
# Epoch 17/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 310.40, Validation MAE: 693.36
# Train RMSE: 380.94, Validation RMSE: 804.52
# Train SMAPE: 19.34, Validation SMAPE: 30.03
# Epoch 18/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 310.40, Validation MAE: 693.38
# Train RMSE: 380.97, Validation RMSE: 804.58
# Train SMAPE: 19.34, Validation SMAPE: 30.03
# Epoch 00019: reducing learning rate of group 0 to 2.5000e-05.
# Epoch 19/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 310.41, Validation MAE: 693.39
# Train RMSE: 380.98, Validation RMSE: 804.60
# Train SMAPE: 19.34, Validation SMAPE: 30.03
# Epoch 20/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 311.36, Validation MAE: 696.06
# Train RMSE: 380.25, Validation RMSE: 810.11
# Train SMAPE: 19.41, Validation SMAPE: 30.15
# Epoch 21/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 311.59, Validation MAE: 697.34
# Train RMSE: 381.52, Validation RMSE: 812.74
# Train SMAPE: 19.40, Validation SMAPE: 30.20
# Epoch 22/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 311.72, Validation MAE: 698.00
# Train RMSE: 382.19, Validation RMSE: 814.10
# Train SMAPE: 19.40, Validation SMAPE: 30.23
# Early stopping triggered after 23 epochs for dataset Detached_House_1.
# Training for dataset: Detached_House_2
# Epoch 1/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.21
# Train MAE: 251.25, Validation MAE: 335.88
# Train RMSE: 329.12, Validation RMSE: 459.07
# Train SMAPE: 30.54, Validation SMAPE: 29.14
# Epoch 2/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 230.12, Validation MAE: 327.61
# Train RMSE: 334.74, Validation RMSE: 471.97
# Train SMAPE: 27.94, Validation SMAPE: 28.30
# Epoch 3/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.96, Validation MAE: 326.47
# Train RMSE: 339.96, Validation RMSE: 476.21
# Train SMAPE: 27.36, Validation SMAPE: 28.18
# Epoch 4/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.29, Validation MAE: 326.03
# Train RMSE: 341.33, Validation RMSE: 476.85
# Train SMAPE: 27.26, Validation SMAPE: 28.13
# Epoch 5/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.15, Validation MAE: 325.56
# Train RMSE: 341.54, Validation RMSE: 476.98
# Train SMAPE: 27.24, Validation SMAPE: 28.08
# Epoch 6/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.98, Validation MAE: 325.01
# Train RMSE: 341.60, Validation RMSE: 476.83
# Train SMAPE: 27.22, Validation SMAPE: 28.02
# Epoch 7/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.73, Validation MAE: 324.88
# Train RMSE: 341.48, Validation RMSE: 476.42
# Train SMAPE: 27.18, Validation SMAPE: 28.01
# Epoch 8/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.62, Validation MAE: 324.88
# Train RMSE: 341.32, Validation RMSE: 476.23
# Train SMAPE: 27.16, Validation SMAPE: 28.01
# Epoch 9/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.60, Validation MAE: 324.89
# Train RMSE: 341.23, Validation RMSE: 476.17
# Train SMAPE: 27.16, Validation SMAPE: 28.01
# Epoch 10/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.59, Validation MAE: 324.90
# Train RMSE: 341.18, Validation RMSE: 476.13
# Train SMAPE: 27.15, Validation SMAPE: 28.02
# Epoch 11/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.57, Validation MAE: 324.91
# Train RMSE: 341.15, Validation RMSE: 476.11
# Train SMAPE: 27.15, Validation SMAPE: 28.02
# Epoch 12/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.55, Validation MAE: 324.92
# Train RMSE: 341.13, Validation RMSE: 476.08
# Train SMAPE: 27.15, Validation SMAPE: 28.02
# Epoch 00036: reducing learning rate of group 0 to 1.2500e-05.
# Epoch 13/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.54, Validation MAE: 324.93
# Train RMSE: 341.11, Validation RMSE: 476.10
# Train SMAPE: 27.15, Validation SMAPE: 28.02
# Epoch 14/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.88, Validation MAE: 324.85
# Train RMSE: 340.56, Validation RMSE: 477.16
# Train SMAPE: 27.20, Validation SMAPE: 28.01
# Epoch 15/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.68, Validation MAE: 324.82
# Train RMSE: 341.01, Validation RMSE: 477.72
# Train SMAPE: 27.17, Validation SMAPE: 28.00
# Epoch 16/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.59, Validation MAE: 324.81
# Train RMSE: 341.21, Validation RMSE: 477.86
# Train SMAPE: 27.15, Validation SMAPE: 28.00
# Early stopping triggered after 17 epochs for dataset Detached_House_2.

# %%
class GRU(nn.Module):
    def __init__(self, num_features):
        super(GRU, self).__init__()
        self.gru = nn.GRU(input_size=num_features, hidden_size=64, batch_first=True,dropout=0.1)
        self.fc = nn.Linear(64, 1)

    def forward(self, x):
        x, _ = self.gru(x)
        output = self.fc(x)
        return output


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if device.type == 'cuda':
    print("Training will be performed on GPU")
else:
    print("Training will be performed on CPU")

learning_rate = 0.001

def train(model, data_loader, optimizer, loss_fn):
    model.train()
    losses = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    for inputs, scaled_targets, future_energy_min_max in data_loader:
        inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
        #print("Scaled Targets:", scaled_targets[0].cpu().numpy())  # Print the first scaled target
        targets_min, targets_max = future_energy_min_max
        targets_min, targets_max = targets_min.to(device), targets_max.to(device)
        #print("Min for targets:", targets_min[0].item())   # Print min value used for scaling for the first target
        #print("Max for targets:", targets_max[0].item())   # Print max value used for scaling for the first target

        outputs = model(inputs)
        #print("Outputs:", outputs[0].detach().cpu().numpy())
        loss = loss_fn(outputs, scaled_targets)
        losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
        #print("Inverse Scaled Targets:", targets[0].cpu().numpy())  # Print the first inverse scaled target
        outputs = inverse_minmax_scale(outputs, targets_min, targets_max)
        #print("Inverse Scaled Outputs:", outputs[0].detach().cpu().numpy())    # Print the first inverse scaled output

        metrics['MAE'].append(mae(outputs, targets).item())
        metrics['RMSE'].append(rmse(outputs, targets).item())
        metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}

def evaluate(model, data_loader, loss_fn):
    model.eval()
    losses = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    with torch.no_grad():
        for inputs, scaled_targets, future_energy_min_max in data_loader:
            inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
            targets_min, targets_max = future_energy_min_max
            targets_min, targets_max = targets_min.to(device), targets_max.to(device)

            outputs = model(inputs)
            loss = loss_fn(outputs, scaled_targets)
            losses.append(loss.item())

            targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
            outputs = inverse_minmax_scale(outputs, targets_min, targets_max)

            metrics['MAE'].append(mae(outputs, targets).item())
            metrics['RMSE'].append(rmse(outputs, targets).item())
            metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}
    
model = GRU(num_features=6).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=1e-7)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)
loss_fn = nn.L1Loss()

def train_and_validate(datasets, num_epochs, patience, loss_fn):
    plots_dir = "./GRU_MSE/"
    
    for dataset_name in datasets['train'].keys():
        print(f"Training for dataset: {dataset_name}")
        
        train_loader = DataLoader(datasets['train'][dataset_name], batch_size=1, shuffle=False)
        val_loader = DataLoader(datasets['val'][dataset_name], batch_size=1, shuffle=False)
        
        best_val_loss = np.inf
        epochs_no_improve = 0

        train_loss_history = []
        val_loss_history = []
        train_mae_history = []
        val_mae_history = []
        train_rmse_history = []
        val_rmse_history = []
        train_smape_history = []
        val_smape_history = []

        for epoch in range(num_epochs):
            train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn)
            val_loss, val_metrics = evaluate(model, val_loader, loss_fn)

            scheduler.step(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1

            if epochs_no_improve == patience:
                print(f"Early stopping triggered after {epoch + 1} epochs for dataset {dataset_name}.")
                break

            train_loss_history.append(train_loss)
            val_loss_history.append(val_loss)
            train_mae_history.append(train_metrics['MAE'])
            val_mae_history.append(val_metrics['MAE'])
            train_rmse_history.append(train_metrics['RMSE'])
            val_rmse_history.append(val_metrics['RMSE'])
            train_smape_history.append(train_metrics['SMAPE'])
            val_smape_history.append(val_metrics['SMAPE'])

            print(f"Epoch {epoch + 1}/{num_epochs} for dataset {dataset_name}")
            print(f"Train Loss: {train_loss:.2f}, Validation Loss: {val_loss:.2f}")
            print(f"Train MAE: {train_metrics['MAE']:.2f}, Validation MAE: {val_metrics['MAE']:.2f}")
            print(f"Train RMSE: {train_metrics['RMSE']:.2f}, Validation RMSE: {val_metrics['RMSE']:.2f}")
            print(f"Train SMAPE: {train_metrics['SMAPE']:.2f}, Validation SMAPE: {val_metrics['SMAPE']:.2f}")

        def plot_metrics(history1, history2, title, ylabel, filename):
            fig = go.Figure()
            fig.add_trace(go.Scatter(y=history1, mode='lines', name='Train'))
            fig.add_trace(go.Scatter(y=history2, mode='lines', name='Validation'))
            fig.update_layout(title=title, xaxis_title='Epoch', yaxis_title=ylabel)
            fig.write_image(f"{plots_dir}/{dataset_name}_{filename}")

        plot_metrics(train_loss_history, val_loss_history, 'Loss vs Epoch', 'Loss', 'drop_loss_plot.png')
        plot_metrics(train_mae_history, val_mae_history, 'MAE vs Epoch', 'MAE', 'drop_mae_plot.png')
        plot_metrics(train_rmse_history, val_rmse_history, 'RMSE vs Epoch', 'RMSE', 'drop_rmse_plot.png')
        plot_metrics(train_smape_history, val_smape_history, 'SMAPE vs Epoch', 'SMAPE', 'drop_smape_plot.png')

        torch.save(model.state_dict(), f'./GRU_MSE/GRU_{loss_fn}_{dataset_name}.pth')

datasets = {
    'train': train_datasets,
    'val': val_datasets,
    'test': test_datasets
}

patience = 10
num_epochs = 500
train_and_validate(datasets, num_epochs, patience,loss_fn)
# Out:
# Training will be performed on GPU
# Training for dataset: Detached_House_1
# Epoch 1/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.91, Validation MAE: 797.29
# Train RMSE: 360.61, Validation RMSE: 993.93
# Train SMAPE: 17.55, Validation SMAPE: 35.03
# Epoch 2/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.03, Validation MAE: 797.45
# Train RMSE: 359.21, Validation RMSE: 993.07
# Train SMAPE: 17.50, Validation SMAPE: 35.06
# Epoch 3/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.48, Validation MAE: 797.42
# Train RMSE: 359.62, Validation RMSE: 993.03
# Train SMAPE: 17.53, Validation SMAPE: 35.06
# Epoch 4/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.47, Validation MAE: 797.40
# Train RMSE: 359.61, Validation RMSE: 993.00
# Train SMAPE: 17.53, Validation SMAPE: 35.06
# Epoch 5/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.47, Validation MAE: 797.39
# Train RMSE: 359.61, Validation RMSE: 992.97
# Train SMAPE: 17.53, Validation SMAPE: 35.06
# Epoch 6/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.47, Validation MAE: 797.37
# Train RMSE: 359.62, Validation RMSE: 992.95
# Train SMAPE: 17.53, Validation SMAPE: 35.06
# Epoch 00007: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 7/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.35
# Train MAE: 280.48, Validation MAE: 797.35
# Train RMSE: 359.62, Validation RMSE: 992.93
# Train SMAPE: 17.53, Validation SMAPE: 35.06
# Epoch 8/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 286.20, Validation MAE: 709.00
# Train RMSE: 363.03, Validation RMSE: 838.09
# Train SMAPE: 17.87, Validation SMAPE: 30.69
# Epoch 9/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 285.94, Validation MAE: 709.00
# Train RMSE: 362.70, Validation RMSE: 838.08
# Train SMAPE: 17.86, Validation SMAPE: 30.69
# Epoch 10/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 285.94, Validation MAE: 708.99
# Train RMSE: 362.70, Validation RMSE: 838.07
# Train SMAPE: 17.86, Validation SMAPE: 30.69
# Epoch 11/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 285.94, Validation MAE: 708.99
# Train RMSE: 362.70, Validation RMSE: 838.07
# Train SMAPE: 17.86, Validation SMAPE: 30.69
# Epoch 12/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 285.94, Validation MAE: 708.98
# Train RMSE: 362.70, Validation RMSE: 838.06
# Train SMAPE: 17.86, Validation SMAPE: 30.69
# Epoch 13/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 285.94, Validation MAE: 708.98
# Train RMSE: 362.70, Validation RMSE: 838.05
# Train SMAPE: 17.86, Validation SMAPE: 30.69
# Epoch 00014: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 14/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.31
# Train MAE: 285.94, Validation MAE: 708.97
# Train RMSE: 362.70, Validation RMSE: 838.05
# Train SMAPE: 17.86, Validation SMAPE: 30.69
# Epoch 15/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.26, Validation MAE: 675.17
# Train RMSE: 367.96, Validation RMSE: 767.09
# Train SMAPE: 18.28, Validation SMAPE: 29.26
# Epoch 16/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.13, Validation MAE: 675.16
# Train RMSE: 367.77, Validation RMSE: 767.09
# Train SMAPE: 18.27, Validation SMAPE: 29.26
# Epoch 17/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.13, Validation MAE: 675.16
# Train RMSE: 367.77, Validation RMSE: 767.09
# Train SMAPE: 18.27, Validation SMAPE: 29.26
# Epoch 18/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.13, Validation MAE: 675.16
# Train RMSE: 367.77, Validation RMSE: 767.09
# Train SMAPE: 18.27, Validation SMAPE: 29.26
# Epoch 19/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.13, Validation MAE: 675.15
# Train RMSE: 367.77, Validation RMSE: 767.08
# Train SMAPE: 18.27, Validation SMAPE: 29.26
# Epoch 20/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.13, Validation MAE: 675.15
# Train RMSE: 367.77, Validation RMSE: 767.08
# Train SMAPE: 18.27, Validation SMAPE: 29.26
# Epoch 00021: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 21/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 293.13, Validation MAE: 675.15
# Train RMSE: 367.77, Validation RMSE: 767.08
# Train SMAPE: 18.27, Validation SMAPE: 29.26
# Epoch 22/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.56, Validation MAE: 668.12
# Train RMSE: 369.57, Validation RMSE: 749.16
# Train SMAPE: 18.56, Validation SMAPE: 29.01
# Epoch 23/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.61, Validation MAE: 668.12
# Train RMSE: 369.44, Validation RMSE: 749.16
# Train SMAPE: 18.56, Validation SMAPE: 29.01
# Epoch 24/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.61, Validation MAE: 668.12
# Train RMSE: 369.44, Validation RMSE: 749.16
# Train SMAPE: 18.56, Validation SMAPE: 29.01
# Epoch 25/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.61, Validation MAE: 668.11
# Train RMSE: 369.44, Validation RMSE: 749.15
# Train SMAPE: 18.56, Validation SMAPE: 29.01
# Epoch 26/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.61, Validation MAE: 668.11
# Train RMSE: 369.44, Validation RMSE: 749.15
# Train SMAPE: 18.56, Validation SMAPE: 29.01
# Epoch 27/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.61, Validation MAE: 668.11
# Train RMSE: 369.44, Validation RMSE: 749.15
# Train SMAPE: 18.56, Validation SMAPE: 29.01
# Epoch 00028: reducing learning rate of group 0 to 6.2500e-05.
# Epoch 28/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 297.61, Validation MAE: 668.11
# Train RMSE: 369.44, Validation RMSE: 749.15
# Train SMAPE: 18.56, Validation SMAPE: 29.00
# Epoch 29/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 301.27, Validation MAE: 668.59
# Train RMSE: 371.76, Validation RMSE: 750.62
# Train SMAPE: 18.80, Validation SMAPE: 29.02
# Epoch 30/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 301.25, Validation MAE: 668.59
# Train RMSE: 371.81, Validation RMSE: 750.62
# Train SMAPE: 18.80, Validation SMAPE: 29.02
# Epoch 31/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 301.25, Validation MAE: 668.59
# Train RMSE: 371.81, Validation RMSE: 750.62
# Train SMAPE: 18.80, Validation SMAPE: 29.02
# Epoch 32/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 301.25, Validation MAE: 668.59
# Train RMSE: 371.81, Validation RMSE: 750.62
# Train SMAPE: 18.80, Validation SMAPE: 29.02
# Epoch 33/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 301.25, Validation MAE: 668.59
# Train RMSE: 371.81, Validation RMSE: 750.62
# Train SMAPE: 18.80, Validation SMAPE: 29.02
# Epoch 00034: reducing learning rate of group 0 to 3.1250e-05.
# Epoch 34/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 301.25, Validation MAE: 668.59
# Train RMSE: 371.81, Validation RMSE: 750.62
# Train SMAPE: 18.80, Validation SMAPE: 29.02
# Epoch 35/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 305.50, Validation MAE: 677.78
# Train RMSE: 375.48, Validation RMSE: 773.01
# Train SMAPE: 19.08, Validation SMAPE: 29.36
# Epoch 36/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 305.53, Validation MAE: 677.80
# Train RMSE: 376.23, Validation RMSE: 773.07
# Train SMAPE: 19.08, Validation SMAPE: 29.36
# Epoch 37/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.30
# Train MAE: 305.54, Validation MAE: 677.80
# Train RMSE: 376.23, Validation RMSE: 773.07
# Train SMAPE: 19.08, Validation SMAPE: 29.36
# Early stopping triggered after 38 epochs for dataset Detached_House_1.
# Training for dataset: Detached_House_2
# Epoch 1/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 229.43, Validation MAE: 352.72
# Train RMSE: 334.93, Validation RMSE: 457.35
# Train SMAPE: 27.67, Validation SMAPE: 30.73
# Epoch 2/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.72, Validation MAE: 353.20
# Train RMSE: 337.91, Validation RMSE: 455.49
# Train SMAPE: 26.95, Validation SMAPE: 30.75
# Epoch 3/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.65, Validation MAE: 354.50
# Train RMSE: 337.76, Validation RMSE: 455.22
# Train SMAPE: 26.92, Validation SMAPE: 30.85
# Epoch 4/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.66, Validation MAE: 354.60
# Train RMSE: 337.53, Validation RMSE: 455.16
# Train SMAPE: 26.92, Validation SMAPE: 30.85
# Epoch 5/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.68, Validation MAE: 354.65
# Train RMSE: 337.47, Validation RMSE: 455.14
# Train SMAPE: 26.92, Validation SMAPE: 30.86
# Epoch 6/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.66, Validation MAE: 354.59
# Train RMSE: 337.46, Validation RMSE: 455.13
# Train SMAPE: 26.92, Validation SMAPE: 30.85
# Epoch 00045: reducing learning rate of group 0 to 1.5625e-05.
# Epoch 7/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.65, Validation MAE: 354.77
# Train RMSE: 337.42, Validation RMSE: 455.09
# Train SMAPE: 26.92, Validation SMAPE: 30.86
# Epoch 8/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.85, Validation MAE: 345.26
# Train RMSE: 336.62, Validation RMSE: 458.98
# Train SMAPE: 27.13, Validation SMAPE: 30.06
# Epoch 9/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.10, Validation MAE: 344.46
# Train RMSE: 337.63, Validation RMSE: 460.24
# Train SMAPE: 27.04, Validation SMAPE: 30.00
# Epoch 10/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.06, Validation MAE: 344.75
# Train RMSE: 337.73, Validation RMSE: 460.62
# Train SMAPE: 27.03, Validation SMAPE: 30.03
# Epoch 11/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.99, Validation MAE: 344.69
# Train RMSE: 337.92, Validation RMSE: 460.83
# Train SMAPE: 27.03, Validation SMAPE: 30.02
# Epoch 12/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.94, Validation MAE: 344.52
# Train RMSE: 338.11, Validation RMSE: 460.99
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 13/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.94, Validation MAE: 344.53
# Train RMSE: 338.14, Validation RMSE: 460.99
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 14/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.93, Validation MAE: 344.54
# Train RMSE: 338.17, Validation RMSE: 461.00
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 15/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.95, Validation MAE: 344.53
# Train RMSE: 338.16, Validation RMSE: 461.01
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 16/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.95, Validation MAE: 344.49
# Train RMSE: 338.20, Validation RMSE: 461.04
# Train SMAPE: 27.02, Validation SMAPE: 30.00
# Epoch 17/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.94, Validation MAE: 344.56
# Train RMSE: 338.21, Validation RMSE: 460.99
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 18/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.95, Validation MAE: 344.57
# Train RMSE: 338.19, Validation RMSE: 460.99
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 19/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.94, Validation MAE: 344.56
# Train RMSE: 338.20, Validation RMSE: 460.99
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 20/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.95, Validation MAE: 344.53
# Train RMSE: 338.19, Validation RMSE: 461.01
# Train SMAPE: 27.02, Validation SMAPE: 30.01
# Epoch 21/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.93, Validation MAE: 344.47
# Train RMSE: 338.22, Validation RMSE: 461.05
# Train SMAPE: 27.02, Validation SMAPE: 30.00
# Epoch 00060: reducing learning rate of group 0 to 7.8125e-06.
# Epoch 22/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 223.91, Validation MAE: 344.47
# Train RMSE: 338.23, Validation RMSE: 461.04
# Train SMAPE: 27.02, Validation SMAPE: 30.00
# Epoch 23/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.85, Validation MAE: 338.19
# Train RMSE: 337.49, Validation RMSE: 466.07
# Train SMAPE: 27.17, Validation SMAPE: 29.43
# Epoch 24/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.22, Validation MAE: 337.82
# Train RMSE: 338.70, Validation RMSE: 466.41
# Train SMAPE: 27.08, Validation SMAPE: 29.40
# Epoch 25/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.21, Validation MAE: 337.67
# Train RMSE: 338.78, Validation RMSE: 466.51
# Train SMAPE: 27.08, Validation SMAPE: 29.38
# Epoch 26/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.21, Validation MAE: 337.52
# Train RMSE: 338.82, Validation RMSE: 466.59
# Train SMAPE: 27.08, Validation SMAPE: 29.37
# Epoch 27/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.22, Validation MAE: 337.40
# Train RMSE: 338.84, Validation RMSE: 466.65
# Train SMAPE: 27.08, Validation SMAPE: 29.35
# Epoch 28/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.22, Validation MAE: 337.35
# Train RMSE: 338.85, Validation RMSE: 466.66
# Train SMAPE: 27.08, Validation SMAPE: 29.35
# Epoch 29/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.23, Validation MAE: 337.18
# Train RMSE: 338.86, Validation RMSE: 466.78
# Train SMAPE: 27.08, Validation SMAPE: 29.33
# Epoch 30/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.24, Validation MAE: 337.15
# Train RMSE: 338.87, Validation RMSE: 466.77
# Train SMAPE: 27.08, Validation SMAPE: 29.33
# Epoch 31/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.24, Validation MAE: 337.15
# Train RMSE: 338.86, Validation RMSE: 466.76
# Train SMAPE: 27.09, Validation SMAPE: 29.33
# Epoch 32/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.26, Validation MAE: 337.11
# Train RMSE: 338.85, Validation RMSE: 466.78
# Train SMAPE: 27.09, Validation SMAPE: 29.32
# Epoch 33/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.25, Validation MAE: 337.10
# Train RMSE: 338.85, Validation RMSE: 466.77
# Train SMAPE: 27.09, Validation SMAPE: 29.32
# Epoch 34/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.26, Validation MAE: 337.08
# Train RMSE: 338.85, Validation RMSE: 466.79
# Train SMAPE: 27.09, Validation SMAPE: 29.32
# Epoch 35/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.25, Validation MAE: 337.08
# Train RMSE: 338.85, Validation RMSE: 466.79
# Train SMAPE: 27.09, Validation SMAPE: 29.32
# Epoch 36/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.25, Validation MAE: 337.07
# Train RMSE: 338.85, Validation RMSE: 466.81
# Train SMAPE: 27.09, Validation SMAPE: 29.32
# Epoch 37/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.24, Validation MAE: 337.05
# Train RMSE: 338.86, Validation RMSE: 466.82
# Train SMAPE: 27.08, Validation SMAPE: 29.32
# Epoch 38/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.24, Validation MAE: 337.05
# Train RMSE: 338.86, Validation RMSE: 466.81
# Train SMAPE: 27.08, Validation SMAPE: 29.32
# Epoch 00077: reducing learning rate of group 0 to 3.9063e-06.
# Epoch 39/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.22
# Train MAE: 224.23, Validation MAE: 337.04
# Train RMSE: 338.87, Validation RMSE: 466.82
# Train SMAPE: 27.08, Validation SMAPE: 29.32
# Epoch 40/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.32, Validation MAE: 332.60
# Train RMSE: 338.20, Validation RMSE: 471.28
# Train SMAPE: 27.24, Validation SMAPE: 28.89
# Epoch 41/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.59, Validation MAE: 332.16
# Train RMSE: 339.10, Validation RMSE: 471.35
# Train SMAPE: 27.14, Validation SMAPE: 28.84
# Epoch 42/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.63, Validation MAE: 331.73
# Train RMSE: 338.99, Validation RMSE: 471.48
# Train SMAPE: 27.15, Validation SMAPE: 28.80
# Epoch 43/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.65, Validation MAE: 331.40
# Train RMSE: 338.95, Validation RMSE: 471.60
# Train SMAPE: 27.15, Validation SMAPE: 28.77
# Epoch 44/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.65, Validation MAE: 330.96
# Train RMSE: 338.95, Validation RMSE: 471.86
# Train SMAPE: 27.15, Validation SMAPE: 28.72
# Epoch 45/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.64, Validation MAE: 330.59
# Train RMSE: 338.95, Validation RMSE: 471.99
# Train SMAPE: 27.15, Validation SMAPE: 28.68
# Epoch 46/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.66, Validation MAE: 330.04
# Train RMSE: 338.94, Validation RMSE: 472.27
# Train SMAPE: 27.15, Validation SMAPE: 28.63
# Epoch 47/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.65, Validation MAE: 329.37
# Train RMSE: 338.97, Validation RMSE: 472.65
# Train SMAPE: 27.15, Validation SMAPE: 28.56
# Epoch 48/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.61, Validation MAE: 328.76
# Train RMSE: 339.02, Validation RMSE: 472.90
# Train SMAPE: 27.14, Validation SMAPE: 28.49
# Epoch 49/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.61, Validation MAE: 328.17
# Train RMSE: 339.04, Validation RMSE: 473.13
# Train SMAPE: 27.14, Validation SMAPE: 28.43
# Epoch 50/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.61, Validation MAE: 327.37
# Train RMSE: 339.06, Validation RMSE: 473.60
# Train SMAPE: 27.14, Validation SMAPE: 28.34
# Epoch 51/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.59, Validation MAE: 326.71
# Train RMSE: 339.08, Validation RMSE: 473.88
# Train SMAPE: 27.14, Validation SMAPE: 28.27
# Epoch 52/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.54, Validation MAE: 326.05
# Train RMSE: 339.11, Validation RMSE: 474.21
# Train SMAPE: 27.13, Validation SMAPE: 28.20
# Epoch 53/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.46, Validation MAE: 325.50
# Train RMSE: 339.15, Validation RMSE: 474.49
# Train SMAPE: 27.12, Validation SMAPE: 28.13
# Epoch 54/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.42, Validation MAE: 325.12
# Train RMSE: 339.15, Validation RMSE: 474.69
# Train SMAPE: 27.12, Validation SMAPE: 28.09
# Epoch 55/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.34, Validation MAE: 324.87
# Train RMSE: 339.18, Validation RMSE: 474.91
# Train SMAPE: 27.10, Validation SMAPE: 28.06
# Epoch 56/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.28, Validation MAE: 324.71
# Train RMSE: 339.21, Validation RMSE: 475.05
# Train SMAPE: 27.10, Validation SMAPE: 28.05
# Epoch 57/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.24, Validation MAE: 324.63
# Train RMSE: 339.20, Validation RMSE: 475.15
# Train SMAPE: 27.09, Validation SMAPE: 28.04
# Epoch 58/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.22, Validation MAE: 324.58
# Train RMSE: 339.21, Validation RMSE: 475.19
# Train SMAPE: 27.09, Validation SMAPE: 28.04
# Epoch 59/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.19, Validation MAE: 324.54
# Train RMSE: 339.21, Validation RMSE: 475.18
# Train SMAPE: 27.08, Validation SMAPE: 28.03
# Epoch 60/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.18, Validation MAE: 324.51
# Train RMSE: 339.21, Validation RMSE: 475.16
# Train SMAPE: 27.08, Validation SMAPE: 28.03
# Epoch 61/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.17, Validation MAE: 324.47
# Train RMSE: 339.22, Validation RMSE: 475.14
# Train SMAPE: 27.08, Validation SMAPE: 28.02
# Epoch 62/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.15, Validation MAE: 324.46
# Train RMSE: 339.23, Validation RMSE: 475.02
# Train SMAPE: 27.07, Validation SMAPE: 28.02
# Epoch 63/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.04, Validation MAE: 324.51
# Train RMSE: 339.71, Validation RMSE: 474.71
# Train SMAPE: 27.05, Validation SMAPE: 28.03
# Epoch 64/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.08, Validation MAE: 324.55
# Train RMSE: 339.88, Validation RMSE: 474.25
# Train SMAPE: 27.05, Validation SMAPE: 28.04
# Epoch 65/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.13, Validation MAE: 324.52
# Train RMSE: 339.77, Validation RMSE: 474.18
# Train SMAPE: 27.05, Validation SMAPE: 28.04
# Epoch 66/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.13, Validation MAE: 324.49
# Train RMSE: 339.74, Validation RMSE: 474.13
# Train SMAPE: 27.05, Validation SMAPE: 28.03
# Epoch 67/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.14, Validation MAE: 324.45
# Train RMSE: 339.73, Validation RMSE: 474.11
# Train SMAPE: 27.05, Validation SMAPE: 28.03
# Epoch 00106: reducing learning rate of group 0 to 1.9531e-06.
# Epoch 68/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.14, Validation MAE: 324.42
# Train RMSE: 339.72, Validation RMSE: 474.06
# Train SMAPE: 27.05, Validation SMAPE: 28.03
# Epoch 69/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.74, Validation MAE: 324.26
# Train RMSE: 339.11, Validation RMSE: 475.43
# Train SMAPE: 27.14, Validation SMAPE: 28.01
# Epoch 70/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.48, Validation MAE: 324.17
# Train RMSE: 339.83, Validation RMSE: 475.93
# Train SMAPE: 27.10, Validation SMAPE: 28.00
# Epoch 71/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.39, Validation MAE: 324.11
# Train RMSE: 339.94, Validation RMSE: 476.16
# Train SMAPE: 27.09, Validation SMAPE: 28.00
# Epoch 72/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.36, Validation MAE: 324.07
# Train RMSE: 339.95, Validation RMSE: 476.26
# Train SMAPE: 27.09, Validation SMAPE: 27.99
# Epoch 73/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 224.35, Validation MAE: 324.04
# Train RMSE: 339.96, Validation RMSE: 476.32
# Train SMAPE: 27.08, Validation SMAPE: 27.99
# Epoch 00112: reducing learning rate of group 0 to 9.7656e-07.
# Early stopping triggered after 74 epochs for dataset Detached_House_2.

# %%
def test(model, data_loader, loss_fn):
    model.eval()
    losses = []
    all_outputs = []
    all_targets = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    with torch.no_grad():
        for inputs, scaled_targets, future_energy_min_max in data_loader:
            inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
            targets_min, targets_max = future_energy_min_max
            targets_min, targets_max = targets_min.to(device), targets_max.to(device)

            outputs = model(inputs)
            loss = loss_fn(outputs, scaled_targets)
            losses.append(loss.item())

            targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
            outputs = inverse_minmax_scale(outputs, targets_min, targets_max)

            metrics['MAE'].append(mae(outputs, targets).item())
            metrics['RMSE'].append(rmse(outputs, targets).item())
            metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}

test_results = {}
for dataset_name in datasets['test'].keys():
    print(f"Testing for dataset: {dataset_name}")
    model = GRU(num_features=6).to(device)
    model.load_state_dict(torch.load(f'./GRU_MSE/GRU_{loss_fn}_{dataset_name}.pth'))

    test_loader = DataLoader(datasets['test'][dataset_name], batch_size=1, shuffle=False)

    test_loss, test_metrics = test(model, test_loader, loss_fn)
    
    print(f"Test Loss for {dataset_name}: {test_loss:.2f}")
    print(f"Test MAE for {dataset_name}: {test_metrics['MAE']:.2f}")
    print(f"Test RMSE for {dataset_name}: {test_metrics['RMSE']:.2f}")
    print(f"Test SMAPE for {dataset_name}: {test_metrics['SMAPE']:.2f}")
    print('-' * 50)

    test_results[dataset_name] = {
        'loss': test_loss,
        'MAE': test_metrics['MAE'],
        'RMSE': test_metrics['RMSE'],
        'SMAPE': test_metrics['SMAPE']
    }

def test_with_values(model, data_loader, loss_fn):
    model.eval()
    all_outputs = []
    all_targets = []

    with torch.no_grad():
        for inputs, scaled_targets, future_energy_min_max in data_loader:
            inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
            targets_min, targets_max = future_energy_min_max
            targets_min, targets_max = targets_min.to(device), targets_max.to(device)

            outputs = model(inputs)

            targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max).cpu().numpy()
            outputs = inverse_minmax_scale(outputs, targets_min, targets_max).cpu().numpy()

            all_outputs.extend(outputs)
            all_targets.extend(targets)
        
    return all_targets, all_outputs

for dataset_name in datasets['test'].keys():
    print(f"Generating values for dataset: {dataset_name}")
    model = GRU(num_features=6).to(device)
    model.load_state_dict(torch.load(f'./GRU_MSE/GRU_{loss_fn}_{dataset_name}.pth'))

    test_loader = DataLoader(datasets['test'][dataset_name], batch_size=1, shuffle=False)

    actual_values, predicted_values = test_with_values(model, test_loader, loss_fn)
    print(len(np.ravel(actual_values)))
    print(len(np.ravel(predicted_values)))
    
    df_results = pd.DataFrame({
        'Actual': actual_values,
        'Predicted': predicted_values
    })

    df_results.to_csv(f"./GRU_MSE/{dataset_name}_results.csv", index=False)
    print(f"Saved results for {dataset_name} to {dataset_name}_results.csv")
# Out:
# Testing for dataset: Detached_House_1
# Test Loss for Detached_House_1: 0.31
# Test MAE for Detached_House_1: 645.24
# Test RMSE for Detached_House_1: 717.64
# Test SMAPE for Detached_House_1: 32.60
# --------------------------------------------------
# Testing for dataset: Detached_House_2
# Test Loss for Detached_House_2: 0.20
# Test MAE for Detached_House_2: 371.69
# Test RMSE for Detached_House_2: 537.68
# Test SMAPE for Detached_House_2: 31.47
# --------------------------------------------------
# Generating values for dataset: Detached_House_1
# 19608
# 19608
# Saved results for Detached_House_1 to Detached_House_1_results.csv
# Generating values for dataset: Detached_House_2
# 19608
# 19608
# Saved results for Detached_House_2 to Detached_House_2_results.csv

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader
import pandas as pd
import torch
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn.functional as F
from torch import nn
import math
import torch
import torch.nn as nn
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(1, 0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]

class Transformer(nn.Module):
    def __init__(self, num_features, d_model, nhead, num_layers):
        super(Transformer, self).__init__()

        self.embedding = nn.Linear(num_features, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        self.transformer = nn.Transformer(d_model, nhead, num_layers)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x):
        x = self.embedding(x)
        x = self.pos_encoder(x)
        x = self.transformer.encoder(x)
        output = self.fc(x)
        return output



device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

if device.type == 'cuda':
    print("Training will be performed on GPU")
else:
    print("Training will be performed on CPU")

learning_rate = 0.0001
def train(model, data_loader, optimizer, loss_fn):
    model.train()
    losses = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    for inputs, scaled_targets, future_energy_min_max in data_loader:
        inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
        targets_min, targets_max = future_energy_min_max
        targets_min, targets_max = targets_min.to(device), targets_max.to(device)
        
        outputs = model(inputs)
        loss = loss_fn(outputs, scaled_targets)
        losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        

        targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
        #print("Inverse Scaled Targets:", targets[0].cpu().numpy())  # Print the first inverse scaled target
        outputs = inverse_minmax_scale(outputs, targets_min, targets_max)
        #print("Inverse Scaled Outputs:", outputs[0].detach().cpu().numpy())    # Print the first inverse scaled output

        metrics['MAE'].append(mae(outputs, targets).item())
        metrics['RMSE'].append(rmse(outputs, targets).item())
        metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}

def evaluate(model, data_loader, loss_fn):
    model.eval()
    losses = []
    metrics = {'MAE': [], 'RMSE': [], 'SMAPE': []}

    with torch.no_grad():
        for inputs, scaled_targets, future_energy_min_max in data_loader:
            inputs, scaled_targets = inputs.to(device), scaled_targets.to(device)
            targets_min, targets_max = future_energy_min_max
            targets_min, targets_max = targets_min.to(device), targets_max.to(device)

            outputs = model(inputs)
            loss = loss_fn(outputs, scaled_targets)
            losses.append(loss.item())

            targets = inverse_minmax_scale(scaled_targets, targets_min, targets_max)
            outputs = inverse_minmax_scale(outputs, targets_min, targets_max)

            metrics['MAE'].append(mae(outputs, targets).item())
            metrics['RMSE'].append(rmse(outputs, targets).item())
            metrics['SMAPE'].append(smape(outputs, targets))

    return np.mean(losses), {k: np.mean(v) for k, v in metrics.items()}
    

model = Transformer(num_features=6, d_model=128, nhead=4, num_layers=2).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=1e-7)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)
loss_fn = nn.L1Loss()

def train_and_validate(datasets, num_epochs, patience,loss_fn):
    plots_dir = "./Transformer_MSE/"
    
    for dataset_name in datasets['train'].keys():
        print(f"Training for dataset: {dataset_name}")
        
        train_loader = DataLoader(datasets['train'][dataset_name], batch_size=1, shuffle=False)
        val_loader = DataLoader(datasets['val'][dataset_name], batch_size=1, shuffle=False)
        
        best_val_loss = np.inf
        epochs_no_improve = 0

        train_loss_history = []
        val_loss_history = []
        train_mae_history = []
        val_mae_history = []
        train_rmse_history = []
        val_rmse_history = []
        train_smape_history = []
        val_smape_history = []

        for epoch in range(num_epochs):
            train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn)
            val_loss, val_metrics = evaluate(model, val_loader, loss_fn)
            scheduler.step(val_loss)
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1

            if epochs_no_improve == patience:
                print(f"Early stopping triggered after {epoch + 1} epochs for dataset {dataset_name}.")
                break

            train_loss_history.append(train_loss)
            val_loss_history.append(val_loss)
            train_mae_history.append(train_metrics['MAE'])
            val_mae_history.append(val_metrics['MAE'])
            train_rmse_history.append(train_metrics['RMSE'])
            val_rmse_history.append(val_metrics['RMSE'])
            train_smape_history.append(train_metrics['SMAPE'])
            val_smape_history.append(val_metrics['SMAPE'])

            print(f"Epoch {epoch + 1}/{num_epochs} for dataset {dataset_name}")
            print(f"Train Loss: {train_loss:.2f}, Validation Loss: {val_loss:.2f}")
            print(f"Train MAE: {train_metrics['MAE']:.2f}, Validation MAE: {val_metrics['MAE']:.2f}")
            print(f"Train RMSE: {train_metrics['RMSE']:.2f}, Validation RMSE: {val_metrics['RMSE']:.2f}")
            print(f"Train SMAPE: {train_metrics['SMAPE']:.2f}, Validation SMAPE: {val_metrics['SMAPE']:.2f}")

        def plot_metrics(history1, history2, title, ylabel, filename):
            fig = go.Figure()
            fig.add_trace(go.Scatter(y=history1, mode='lines', name='Train'))
            fig.add_trace(go.Scatter(y=history2, mode='lines', name='Validation'))
            fig.update_layout(title=title, xaxis_title='Epoch', yaxis_title=ylabel)
            fig.write_image(f"{plots_dir}/{dataset_name}_{filename}")

        plot_metrics(train_loss_history, val_loss_history, 'Loss vs Epoch', 'Loss', 'drop_loss_plot.png')
        plot_metrics(train_mae_history, val_mae_history, 'MAE vs Epoch', 'MAE', 'drop_mae_plot.png')
        plot_metrics(train_rmse_history, val_rmse_history, 'RMSE vs Epoch', 'RMSE', 'drop_rmse_plot.png')
        plot_metrics(train_smape_history, val_smape_history, 'SMAPE vs Epoch', 'SMAPE', 'drop_smape_plot.png')

        torch.save(model.state_dict(), f'./Transformer_MSE/Transformer_{loss_fn}_{dataset_name}.pth')

datasets = {
    'train': train_datasets,
    'val': val_datasets,
    'test': test_datasets
}



patience = 10
num_epochs = 500

train_and_validate(datasets, num_epochs, patience,loss_fn)
# Out:
# Training will be performed on GPU
# Training for dataset: Detached_House_1
# Epoch 1/500 for dataset Detached_House_1
# Train Loss: 0.28, Validation Loss: 0.32
# Train MAE: 344.49, Validation MAE: 729.57
# Train RMSE: 425.51, Validation RMSE: 875.47
# Train SMAPE: 22.31, Validation SMAPE: 31.66
# Epoch 2/500 for dataset Detached_House_1
# Train Loss: 0.26, Validation Loss: 0.32
# Train MAE: 319.40, Validation MAE: 717.42
# Train RMSE: 395.62, Validation RMSE: 861.89
# Train SMAPE: 20.47, Validation SMAPE: 31.05
# Epoch 3/500 for dataset Detached_House_1
# Train Loss: 0.25, Validation Loss: 0.32
# Train MAE: 310.78, Validation MAE: 718.66
# Train RMSE: 386.36, Validation RMSE: 870.14
# Train SMAPE: 19.78, Validation SMAPE: 31.06
# Epoch 4/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 304.24, Validation MAE: 701.21
# Train RMSE: 379.29, Validation RMSE: 841.65
# Train SMAPE: 19.35, Validation SMAPE: 30.24
# Epoch 5/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 299.44, Validation MAE: 697.85
# Train RMSE: 374.00, Validation RMSE: 839.66
# Train SMAPE: 18.97, Validation SMAPE: 30.06
# Epoch 6/500 for dataset Detached_House_1
# Train Loss: 0.24, Validation Loss: 0.31
# Train MAE: 297.32, Validation MAE: 691.10
# Train RMSE: 371.89, Validation RMSE: 829.96
# Train SMAPE: 18.81, Validation SMAPE: 29.73
# Epoch 7/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.31
# Train MAE: 294.47, Validation MAE: 689.61
# Train RMSE: 368.79, Validation RMSE: 830.37
# Train SMAPE: 18.59, Validation SMAPE: 29.64
# Epoch 8/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 292.03, Validation MAE: 684.15
# Train RMSE: 366.04, Validation RMSE: 822.12
# Train SMAPE: 18.44, Validation SMAPE: 29.38
# Epoch 9/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 291.04, Validation MAE: 678.97
# Train RMSE: 364.45, Validation RMSE: 814.14
# Train SMAPE: 18.34, Validation SMAPE: 29.14
# Epoch 10/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 289.42, Validation MAE: 684.79
# Train RMSE: 363.61, Validation RMSE: 828.67
# Train SMAPE: 18.25, Validation SMAPE: 29.36
# Epoch 11/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 288.81, Validation MAE: 684.04
# Train RMSE: 362.36, Validation RMSE: 829.64
# Train SMAPE: 18.19, Validation SMAPE: 29.30
# Epoch 12/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 287.68, Validation MAE: 672.43
# Train RMSE: 361.56, Validation RMSE: 808.82
# Train SMAPE: 18.11, Validation SMAPE: 28.80
# Epoch 13/500 for dataset Detached_House_1
# Train Loss: 0.23, Validation Loss: 0.30
# Train MAE: 285.89, Validation MAE: 671.74
# Train RMSE: 359.81, Validation RMSE: 810.22
# Train SMAPE: 17.99, Validation SMAPE: 28.74
# Epoch 14/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 285.06, Validation MAE: 676.99
# Train RMSE: 358.62, Validation RMSE: 822.70
# Train SMAPE: 17.95, Validation SMAPE: 28.94
# Epoch 15/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 284.27, Validation MAE: 676.51
# Train RMSE: 357.68, Validation RMSE: 823.62
# Train SMAPE: 17.89, Validation SMAPE: 28.90
# Epoch 16/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 284.01, Validation MAE: 671.61
# Train RMSE: 357.63, Validation RMSE: 815.80
# Train SMAPE: 17.87, Validation SMAPE: 28.68
# Epoch 17/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 282.76, Validation MAE: 677.40
# Train RMSE: 356.11, Validation RMSE: 828.36
# Train SMAPE: 17.79, Validation SMAPE: 28.92
# Epoch 18/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 282.21, Validation MAE: 675.14
# Train RMSE: 355.98, Validation RMSE: 825.89
# Train SMAPE: 17.75, Validation SMAPE: 28.82
# Epoch 19/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 281.53, Validation MAE: 676.73
# Train RMSE: 355.06, Validation RMSE: 829.68
# Train SMAPE: 17.71, Validation SMAPE: 28.91
# Epoch 20/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 280.25, Validation MAE: 669.38
# Train RMSE: 353.73, Validation RMSE: 818.03
# Train SMAPE: 17.63, Validation SMAPE: 28.57
# Epoch 21/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 280.35, Validation MAE: 669.21
# Train RMSE: 353.96, Validation RMSE: 818.51
# Train SMAPE: 17.63, Validation SMAPE: 28.58
# Epoch 22/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 279.46, Validation MAE: 676.05
# Train RMSE: 353.01, Validation RMSE: 830.27
# Train SMAPE: 17.56, Validation SMAPE: 28.98
# Epoch 23/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 279.09, Validation MAE: 669.70
# Train RMSE: 352.61, Validation RMSE: 820.32
# Train SMAPE: 17.55, Validation SMAPE: 28.69
# Epoch 24/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 278.81, Validation MAE: 667.58
# Train RMSE: 352.87, Validation RMSE: 817.07
# Train SMAPE: 17.53, Validation SMAPE: 28.64
# Epoch 25/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 277.77, Validation MAE: 674.38
# Train RMSE: 351.07, Validation RMSE: 827.57
# Train SMAPE: 17.47, Validation SMAPE: 29.10
# Epoch 26/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 276.84, Validation MAE: 667.35
# Train RMSE: 349.74, Validation RMSE: 816.60
# Train SMAPE: 17.43, Validation SMAPE: 28.78
# Epoch 27/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 275.89, Validation MAE: 669.09
# Train RMSE: 349.23, Validation RMSE: 819.07
# Train SMAPE: 17.36, Validation SMAPE: 28.99
# Epoch 28/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 275.38, Validation MAE: 670.28
# Train RMSE: 348.45, Validation RMSE: 820.68
# Train SMAPE: 17.32, Validation SMAPE: 29.15
# Epoch 29/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 274.90, Validation MAE: 671.49
# Train RMSE: 347.71, Validation RMSE: 822.28
# Train SMAPE: 17.32, Validation SMAPE: 29.34
# Epoch 30/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 274.02, Validation MAE: 677.22
# Train RMSE: 347.35, Validation RMSE: 830.73
# Train SMAPE: 17.26, Validation SMAPE: 29.81
# Epoch 31/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 273.73, Validation MAE: 676.71
# Train RMSE: 346.69, Validation RMSE: 829.73
# Train SMAPE: 17.23, Validation SMAPE: 29.91
# Epoch 00032: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 32/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.30
# Train MAE: 272.63, Validation MAE: 676.83
# Train RMSE: 345.71, Validation RMSE: 829.62
# Train SMAPE: 17.17, Validation SMAPE: 30.09
# Epoch 33/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 277.76, Validation MAE: 615.30
# Train RMSE: 348.72, Validation RMSE: 732.11
# Train SMAPE: 17.48, Validation SMAPE: 26.47
# Epoch 34/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 277.27, Validation MAE: 614.64
# Train RMSE: 347.70, Validation RMSE: 731.05
# Train SMAPE: 17.44, Validation SMAPE: 26.48
# Epoch 35/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 277.24, Validation MAE: 614.62
# Train RMSE: 348.00, Validation RMSE: 731.05
# Train SMAPE: 17.43, Validation SMAPE: 26.53
# Epoch 36/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 276.91, Validation MAE: 614.07
# Train RMSE: 347.53, Validation RMSE: 730.14
# Train SMAPE: 17.41, Validation SMAPE: 26.55
# Epoch 37/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 277.02, Validation MAE: 611.38
# Train RMSE: 347.82, Validation RMSE: 725.70
# Train SMAPE: 17.41, Validation SMAPE: 26.46
# Epoch 38/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 275.78, Validation MAE: 614.32
# Train RMSE: 346.58, Validation RMSE: 730.59
# Train SMAPE: 17.35, Validation SMAPE: 26.69
# Epoch 39/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 275.78, Validation MAE: 615.75
# Train RMSE: 346.28, Validation RMSE: 732.95
# Train SMAPE: 17.35, Validation SMAPE: 26.84
# Epoch 40/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 275.03, Validation MAE: 613.56
# Train RMSE: 345.77, Validation RMSE: 729.37
# Train SMAPE: 17.30, Validation SMAPE: 26.79
# Epoch 41/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 275.27, Validation MAE: 615.00
# Train RMSE: 345.92, Validation RMSE: 731.81
# Train SMAPE: 17.34, Validation SMAPE: 26.95
# Epoch 42/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.27
# Train MAE: 274.51, Validation MAE: 616.82
# Train RMSE: 345.00, Validation RMSE: 734.87
# Train SMAPE: 17.28, Validation SMAPE: 27.13
# Epoch 00043: reducing learning rate of group 0 to 2.5000e-05.
# Epoch 43/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.28
# Train MAE: 275.01, Validation MAE: 619.18
# Train RMSE: 345.50, Validation RMSE: 738.76
# Train SMAPE: 17.33, Validation SMAPE: 27.35
# Epoch 44/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.01, Validation MAE: 585.82
# Train RMSE: 346.89, Validation RMSE: 682.38
# Train SMAPE: 17.51, Validation SMAPE: 25.33
# Epoch 45/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.16, Validation MAE: 587.08
# Train RMSE: 346.88, Validation RMSE: 684.56
# Train SMAPE: 17.51, Validation SMAPE: 25.42
# Epoch 46/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.06, Validation MAE: 586.10
# Train RMSE: 346.74, Validation RMSE: 682.93
# Train SMAPE: 17.49, Validation SMAPE: 25.39
# Epoch 47/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 277.45, Validation MAE: 587.80
# Train RMSE: 346.27, Validation RMSE: 685.87
# Train SMAPE: 17.47, Validation SMAPE: 25.52
# Epoch 48/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 277.60, Validation MAE: 588.82
# Train RMSE: 346.32, Validation RMSE: 687.57
# Train SMAPE: 17.47, Validation SMAPE: 25.61
# Epoch 49/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 277.18, Validation MAE: 588.57
# Train RMSE: 345.69, Validation RMSE: 687.16
# Train SMAPE: 17.45, Validation SMAPE: 25.63
# Epoch 00050: reducing learning rate of group 0 to 1.2500e-05.
# Epoch 50/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 277.36, Validation MAE: 586.54
# Train RMSE: 346.26, Validation RMSE: 683.75
# Train SMAPE: 17.46, Validation SMAPE: 25.53
# Epoch 51/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.10, Validation MAE: 579.65
# Train RMSE: 347.11, Validation RMSE: 672.37
# Train SMAPE: 17.56, Validation SMAPE: 25.11
# Epoch 52/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.64, Validation MAE: 579.73
# Train RMSE: 347.57, Validation RMSE: 672.52
# Train SMAPE: 17.60, Validation SMAPE: 25.12
# Epoch 53/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.07, Validation MAE: 579.89
# Train RMSE: 346.64, Validation RMSE: 672.80
# Train SMAPE: 17.57, Validation SMAPE: 25.13
# Epoch 54/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.00, Validation MAE: 580.00
# Train RMSE: 346.74, Validation RMSE: 673.00
# Train SMAPE: 17.56, Validation SMAPE: 25.14
# Epoch 55/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.07, Validation MAE: 580.87
# Train RMSE: 347.48, Validation RMSE: 674.47
# Train SMAPE: 17.56, Validation SMAPE: 25.20
# Epoch 56/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.13, Validation MAE: 579.62
# Train RMSE: 347.28, Validation RMSE: 672.40
# Train SMAPE: 17.55, Validation SMAPE: 25.13
# Epoch 57/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.88, Validation MAE: 579.03
# Train RMSE: 346.93, Validation RMSE: 671.44
# Train SMAPE: 17.57, Validation SMAPE: 25.10
# Epoch 58/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.92, Validation MAE: 579.94
# Train RMSE: 347.10, Validation RMSE: 672.96
# Train SMAPE: 17.56, Validation SMAPE: 25.16
# Epoch 59/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.36, Validation MAE: 579.47
# Train RMSE: 347.19, Validation RMSE: 672.21
# Train SMAPE: 17.57, Validation SMAPE: 25.14
# Epoch 60/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.17, Validation MAE: 579.77
# Train RMSE: 347.25, Validation RMSE: 672.73
# Train SMAPE: 17.57, Validation SMAPE: 25.16
# Epoch 61/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.99, Validation MAE: 579.15
# Train RMSE: 346.75, Validation RMSE: 671.72
# Train SMAPE: 17.57, Validation SMAPE: 25.13
# Epoch 62/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 278.89, Validation MAE: 579.53
# Train RMSE: 346.97, Validation RMSE: 672.37
# Train SMAPE: 17.54, Validation SMAPE: 25.16
# Epoch 00063: reducing learning rate of group 0 to 6.2500e-06.
# Epoch 63/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.38, Validation MAE: 580.74
# Train RMSE: 347.04, Validation RMSE: 674.33
# Train SMAPE: 17.57, Validation SMAPE: 25.24
# Epoch 64/500 for dataset Detached_House_1
# Train Loss: 0.22, Validation Loss: 0.26
# Train MAE: 279.72, Validation MAE: 580.49
# Train RMSE: 347.39, Validation RMSE: 673.93
# Train SMAPE: 17.59, Validation SMAPE: 25.23
# Early stopping triggered after 65 epochs for dataset Detached_House_1.
# Training for dataset: Detached_House_2
# Epoch 1/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.25
# Train MAE: 252.71, Validation MAE: 383.22
# Train RMSE: 355.82, Validation RMSE: 479.08
# Train SMAPE: 30.70, Validation SMAPE: 32.81
# Epoch 2/500 for dataset Detached_House_2
# Train Loss: 0.23, Validation Loss: 0.24
# Train MAE: 272.87, Validation MAE: 377.81
# Train RMSE: 364.58, Validation RMSE: 473.19
# Train SMAPE: 32.15, Validation SMAPE: 32.41
# Epoch 3/500 for dataset Detached_House_2
# Train Loss: 0.23, Validation Loss: 0.24
# Train MAE: 268.62, Validation MAE: 372.90
# Train RMSE: 361.59, Validation RMSE: 468.09
# Train SMAPE: 31.64, Validation SMAPE: 32.05
# Epoch 4/500 for dataset Detached_House_2
# Train Loss: 0.23, Validation Loss: 0.24
# Train MAE: 265.29, Validation MAE: 367.65
# Train RMSE: 358.58, Validation RMSE: 463.36
# Train SMAPE: 31.32, Validation SMAPE: 31.67
# Epoch 5/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.23
# Train MAE: 261.72, Validation MAE: 362.94
# Train RMSE: 355.63, Validation RMSE: 459.36
# Train SMAPE: 30.92, Validation SMAPE: 31.33
# Epoch 6/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.23
# Train MAE: 259.05, Validation MAE: 360.00
# Train RMSE: 353.52, Validation RMSE: 456.29
# Train SMAPE: 30.62, Validation SMAPE: 31.10
# Epoch 7/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.23
# Train MAE: 256.59, Validation MAE: 356.07
# Train RMSE: 351.87, Validation RMSE: 453.31
# Train SMAPE: 30.36, Validation SMAPE: 30.81
# Epoch 8/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.23
# Train MAE: 253.45, Validation MAE: 354.14
# Train RMSE: 349.24, Validation RMSE: 451.09
# Train SMAPE: 30.01, Validation SMAPE: 30.65
# Epoch 9/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.23
# Train MAE: 252.18, Validation MAE: 351.65
# Train RMSE: 348.35, Validation RMSE: 448.98
# Train SMAPE: 29.90, Validation SMAPE: 30.46
# Epoch 10/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.23
# Train MAE: 249.57, Validation MAE: 347.91
# Train RMSE: 346.62, Validation RMSE: 446.93
# Train SMAPE: 29.58, Validation SMAPE: 30.18
# Epoch 11/500 for dataset Detached_House_2
# Train Loss: 0.22, Validation Loss: 0.22
# Train MAE: 247.98, Validation MAE: 346.78
# Train RMSE: 345.40, Validation RMSE: 445.51
# Train SMAPE: 29.43, Validation SMAPE: 30.08
# Epoch 12/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 246.55, Validation MAE: 345.02
# Train RMSE: 344.58, Validation RMSE: 444.16
# Train SMAPE: 29.25, Validation SMAPE: 29.95
# Epoch 13/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 245.53, Validation MAE: 342.24
# Train RMSE: 344.13, Validation RMSE: 442.93
# Train SMAPE: 29.16, Validation SMAPE: 29.73
# Epoch 14/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 243.92, Validation MAE: 340.35
# Train RMSE: 343.18, Validation RMSE: 441.96
# Train SMAPE: 28.99, Validation SMAPE: 29.57
# Epoch 15/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 242.45, Validation MAE: 339.45
# Train RMSE: 342.39, Validation RMSE: 441.14
# Train SMAPE: 28.81, Validation SMAPE: 29.50
# Epoch 16/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 241.69, Validation MAE: 338.90
# Train RMSE: 341.65, Validation RMSE: 440.41
# Train SMAPE: 28.76, Validation SMAPE: 29.45
# Epoch 17/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 240.35, Validation MAE: 337.93
# Train RMSE: 341.02, Validation RMSE: 439.78
# Train SMAPE: 28.59, Validation SMAPE: 29.37
# Epoch 18/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 239.71, Validation MAE: 335.68
# Train RMSE: 340.68, Validation RMSE: 439.34
# Train SMAPE: 28.54, Validation SMAPE: 29.19
# Epoch 19/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 238.49, Validation MAE: 335.88
# Train RMSE: 339.78, Validation RMSE: 438.82
# Train SMAPE: 28.41, Validation SMAPE: 29.20
# Epoch 20/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 238.11, Validation MAE: 335.20
# Train RMSE: 339.91, Validation RMSE: 438.43
# Train SMAPE: 28.37, Validation SMAPE: 29.14
# Epoch 21/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 237.12, Validation MAE: 333.59
# Train RMSE: 339.43, Validation RMSE: 438.23
# Train SMAPE: 28.25, Validation SMAPE: 29.01
# Epoch 22/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 236.08, Validation MAE: 332.36
# Train RMSE: 338.95, Validation RMSE: 438.07
# Train SMAPE: 28.15, Validation SMAPE: 28.91
# Epoch 23/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 235.97, Validation MAE: 331.95
# Train RMSE: 339.00, Validation RMSE: 437.84
# Train SMAPE: 28.17, Validation SMAPE: 28.87
# Epoch 24/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.22
# Train MAE: 235.02, Validation MAE: 331.96
# Train RMSE: 338.63, Validation RMSE: 437.56
# Train SMAPE: 28.04, Validation SMAPE: 28.88
# Epoch 25/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 234.55, Validation MAE: 330.27
# Train RMSE: 338.34, Validation RMSE: 437.68
# Train SMAPE: 28.00, Validation SMAPE: 28.73
# Epoch 26/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 234.08, Validation MAE: 330.24
# Train RMSE: 338.08, Validation RMSE: 437.49
# Train SMAPE: 27.94, Validation SMAPE: 28.73
# Epoch 27/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 233.55, Validation MAE: 330.28
# Train RMSE: 338.06, Validation RMSE: 437.30
# Train SMAPE: 27.89, Validation SMAPE: 28.74
# Epoch 28/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 233.09, Validation MAE: 329.43
# Train RMSE: 337.89, Validation RMSE: 437.36
# Train SMAPE: 27.84, Validation SMAPE: 28.67
# Epoch 29/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 232.42, Validation MAE: 329.51
# Train RMSE: 337.04, Validation RMSE: 437.21
# Train SMAPE: 27.77, Validation SMAPE: 28.67
# Epoch 30/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 232.18, Validation MAE: 329.02
# Train RMSE: 337.39, Validation RMSE: 437.23
# Train SMAPE: 27.74, Validation SMAPE: 28.63
# Epoch 31/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 231.81, Validation MAE: 328.58
# Train RMSE: 336.90, Validation RMSE: 437.27
# Train SMAPE: 27.71, Validation SMAPE: 28.59
# Epoch 32/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 231.75, Validation MAE: 328.67
# Train RMSE: 337.36, Validation RMSE: 437.17
# Train SMAPE: 27.71, Validation SMAPE: 28.60
# Epoch 33/500 for dataset Detached_House_2
# Train Loss: 0.21, Validation Loss: 0.21
# Train MAE: 231.33, Validation MAE: 327.74
# Train RMSE: 336.73, Validation RMSE: 437.40
# Train SMAPE: 27.66, Validation SMAPE: 28.52
# Epoch 34/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 230.93, Validation MAE: 327.49
# Train RMSE: 337.01, Validation RMSE: 437.43
# Train SMAPE: 27.63, Validation SMAPE: 28.50
# Epoch 35/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 230.52, Validation MAE: 327.39
# Train RMSE: 337.04, Validation RMSE: 437.43
# Train SMAPE: 27.58, Validation SMAPE: 28.49
# Epoch 36/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 230.39, Validation MAE: 327.92
# Train RMSE: 336.67, Validation RMSE: 437.23
# Train SMAPE: 27.57, Validation SMAPE: 28.54
# Epoch 37/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 229.87, Validation MAE: 327.31
# Train RMSE: 336.38, Validation RMSE: 437.42
# Train SMAPE: 27.50, Validation SMAPE: 28.49
# Epoch 38/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 229.65, Validation MAE: 326.65
# Train RMSE: 336.57, Validation RMSE: 437.66
# Train SMAPE: 27.49, Validation SMAPE: 28.43
# Epoch 39/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 229.57, Validation MAE: 327.73
# Train RMSE: 336.70, Validation RMSE: 437.28
# Train SMAPE: 27.48, Validation SMAPE: 28.53
# Epoch 40/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 229.80, Validation MAE: 326.13
# Train RMSE: 337.06, Validation RMSE: 437.89
# Train SMAPE: 27.51, Validation SMAPE: 28.38
# Epoch 41/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 229.09, Validation MAE: 326.54
# Train RMSE: 336.69, Validation RMSE: 437.75
# Train SMAPE: 27.44, Validation SMAPE: 28.42
# Epoch 42/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.99, Validation MAE: 326.48
# Train RMSE: 336.19, Validation RMSE: 437.80
# Train SMAPE: 27.42, Validation SMAPE: 28.42
# Epoch 43/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 229.01, Validation MAE: 326.15
# Train RMSE: 336.55, Validation RMSE: 437.97
# Train SMAPE: 27.43, Validation SMAPE: 28.39
# Epoch 44/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.91, Validation MAE: 326.50
# Train RMSE: 336.78, Validation RMSE: 437.86
# Train SMAPE: 27.43, Validation SMAPE: 28.42
# Epoch 45/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.69, Validation MAE: 326.21
# Train RMSE: 336.40, Validation RMSE: 438.03
# Train SMAPE: 27.39, Validation SMAPE: 28.39
# Epoch 46/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.20, Validation MAE: 325.60
# Train RMSE: 336.54, Validation RMSE: 438.34
# Train SMAPE: 27.33, Validation SMAPE: 28.34
# Epoch 47/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.15, Validation MAE: 325.85
# Train RMSE: 336.30, Validation RMSE: 438.28
# Train SMAPE: 27.34, Validation SMAPE: 28.36
# Epoch 48/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.95, Validation MAE: 325.89
# Train RMSE: 336.26, Validation RMSE: 438.32
# Train SMAPE: 27.31, Validation SMAPE: 28.36
# Epoch 49/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.02, Validation MAE: 325.09
# Train RMSE: 336.32, Validation RMSE: 438.75
# Train SMAPE: 27.34, Validation SMAPE: 28.29
# Epoch 50/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.80, Validation MAE: 325.11
# Train RMSE: 336.75, Validation RMSE: 438.81
# Train SMAPE: 27.31, Validation SMAPE: 28.29
# Epoch 51/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.71, Validation MAE: 324.90
# Train RMSE: 336.38, Validation RMSE: 438.97
# Train SMAPE: 27.30, Validation SMAPE: 28.27
# Epoch 52/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.45, Validation MAE: 325.01
# Train RMSE: 336.53, Validation RMSE: 438.98
# Train SMAPE: 27.27, Validation SMAPE: 28.28
# Epoch 53/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.23, Validation MAE: 325.31
# Train RMSE: 336.12, Validation RMSE: 438.90
# Train SMAPE: 27.25, Validation SMAPE: 28.31
# Epoch 54/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.17, Validation MAE: 325.55
# Train RMSE: 335.99, Validation RMSE: 438.85
# Train SMAPE: 27.23, Validation SMAPE: 28.33
# Epoch 55/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.12, Validation MAE: 325.12
# Train RMSE: 336.27, Validation RMSE: 439.13
# Train SMAPE: 27.23, Validation SMAPE: 28.29
# Epoch 56/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.07, Validation MAE: 325.29
# Train RMSE: 335.96, Validation RMSE: 439.11
# Train SMAPE: 27.23, Validation SMAPE: 28.30
# Epoch 57/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.27, Validation MAE: 325.80
# Train RMSE: 336.52, Validation RMSE: 438.93
# Train SMAPE: 27.27, Validation SMAPE: 28.35
# Epoch 58/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.11, Validation MAE: 325.84
# Train RMSE: 336.23, Validation RMSE: 438.99
# Train SMAPE: 27.25, Validation SMAPE: 28.35
# Epoch 59/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.03, Validation MAE: 324.73
# Train RMSE: 336.47, Validation RMSE: 439.63
# Train SMAPE: 27.22, Validation SMAPE: 28.25
# Epoch 60/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.65, Validation MAE: 324.81
# Train RMSE: 336.30, Validation RMSE: 439.66
# Train SMAPE: 27.19, Validation SMAPE: 28.26
# Epoch 61/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.85, Validation MAE: 325.42
# Train RMSE: 336.32, Validation RMSE: 439.41
# Train SMAPE: 27.21, Validation SMAPE: 28.31
# Epoch 62/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.63, Validation MAE: 325.10
# Train RMSE: 336.15, Validation RMSE: 439.65
# Train SMAPE: 27.19, Validation SMAPE: 28.28
# Epoch 63/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.26, Validation MAE: 324.59
# Train RMSE: 335.96, Validation RMSE: 440.00
# Train SMAPE: 27.15, Validation SMAPE: 28.23
# Epoch 64/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.56, Validation MAE: 325.05
# Train RMSE: 336.14, Validation RMSE: 439.82
# Train SMAPE: 27.19, Validation SMAPE: 28.28
# Epoch 65/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.65, Validation MAE: 324.62
# Train RMSE: 336.82, Validation RMSE: 440.13
# Train SMAPE: 27.20, Validation SMAPE: 28.24
# Epoch 66/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.19, Validation MAE: 324.79
# Train RMSE: 336.26, Validation RMSE: 440.10
# Train SMAPE: 27.15, Validation SMAPE: 28.25
# Epoch 67/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.23, Validation MAE: 324.67
# Train RMSE: 336.69, Validation RMSE: 440.25
# Train SMAPE: 27.16, Validation SMAPE: 28.24
# Epoch 68/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.37, Validation MAE: 324.27
# Train RMSE: 336.63, Validation RMSE: 440.56
# Train SMAPE: 27.16, Validation SMAPE: 28.20
# Epoch 69/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.25, Validation MAE: 324.83
# Train RMSE: 336.83, Validation RMSE: 440.29
# Train SMAPE: 27.16, Validation SMAPE: 28.25
# Epoch 70/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.93, Validation MAE: 324.24
# Train RMSE: 336.32, Validation RMSE: 440.72
# Train SMAPE: 27.11, Validation SMAPE: 28.20
# Epoch 71/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.95, Validation MAE: 324.28
# Train RMSE: 336.47, Validation RMSE: 440.75
# Train SMAPE: 27.11, Validation SMAPE: 28.20
# Epoch 72/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.82, Validation MAE: 324.30
# Train RMSE: 336.16, Validation RMSE: 440.82
# Train SMAPE: 27.12, Validation SMAPE: 28.20
# Epoch 73/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.69, Validation MAE: 324.31
# Train RMSE: 336.47, Validation RMSE: 440.88
# Train SMAPE: 27.09, Validation SMAPE: 28.20
# Epoch 74/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.80, Validation MAE: 324.61
# Train RMSE: 336.58, Validation RMSE: 440.76
# Train SMAPE: 27.10, Validation SMAPE: 28.23
# Epoch 75/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.83, Validation MAE: 324.60
# Train RMSE: 336.73, Validation RMSE: 440.84
# Train SMAPE: 27.11, Validation SMAPE: 28.23
# Epoch 76/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.90, Validation MAE: 324.05
# Train RMSE: 336.61, Validation RMSE: 441.25
# Train SMAPE: 27.13, Validation SMAPE: 28.18
# Epoch 77/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.75, Validation MAE: 324.41
# Train RMSE: 336.65, Validation RMSE: 441.09
# Train SMAPE: 27.10, Validation SMAPE: 28.21
# Epoch 78/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.54, Validation MAE: 324.36
# Train RMSE: 336.57, Validation RMSE: 441.19
# Train SMAPE: 27.08, Validation SMAPE: 28.20
# Epoch 79/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.75, Validation MAE: 324.67
# Train RMSE: 336.26, Validation RMSE: 441.07
# Train SMAPE: 27.11, Validation SMAPE: 28.23
# Epoch 80/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.95, Validation MAE: 325.17
# Train RMSE: 336.49, Validation RMSE: 440.83
# Train SMAPE: 27.14, Validation SMAPE: 28.28
# Epoch 81/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.69, Validation MAE: 324.22
# Train RMSE: 336.27, Validation RMSE: 441.50
# Train SMAPE: 27.11, Validation SMAPE: 28.19
# Epoch 00147: reducing learning rate of group 0 to 3.1250e-06.
# Epoch 82/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.46, Validation MAE: 324.89
# Train RMSE: 336.22, Validation RMSE: 441.13
# Train SMAPE: 27.08, Validation SMAPE: 28.25
# Epoch 83/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.34, Validation MAE: 318.20
# Train RMSE: 335.46, Validation RMSE: 447.56
# Train SMAPE: 27.45, Validation SMAPE: 27.60
# Epoch 84/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.20, Validation MAE: 317.93
# Train RMSE: 336.31, Validation RMSE: 448.03
# Train SMAPE: 27.19, Validation SMAPE: 27.57
# Epoch 85/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.23, Validation MAE: 318.13
# Train RMSE: 336.78, Validation RMSE: 447.83
# Train SMAPE: 27.20, Validation SMAPE: 27.59
# Epoch 86/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.01, Validation MAE: 317.97
# Train RMSE: 336.53, Validation RMSE: 448.14
# Train SMAPE: 27.17, Validation SMAPE: 27.57
# Epoch 87/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.19, Validation MAE: 317.99
# Train RMSE: 336.70, Validation RMSE: 448.19
# Train SMAPE: 27.19, Validation SMAPE: 27.57
# Epoch 88/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.99, Validation MAE: 318.23
# Train RMSE: 336.49, Validation RMSE: 447.91
# Train SMAPE: 27.17, Validation SMAPE: 27.60
# Epoch 89/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.16, Validation MAE: 318.10
# Train RMSE: 336.78, Validation RMSE: 448.19
# Train SMAPE: 27.19, Validation SMAPE: 27.58
# Epoch 90/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.84, Validation MAE: 317.86
# Train RMSE: 336.84, Validation RMSE: 448.63
# Train SMAPE: 27.15, Validation SMAPE: 27.56
# Epoch 91/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.09, Validation MAE: 318.02
# Train RMSE: 336.84, Validation RMSE: 448.47
# Train SMAPE: 27.19, Validation SMAPE: 27.57
# Epoch 92/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.90, Validation MAE: 318.35
# Train RMSE: 336.65, Validation RMSE: 448.05
# Train SMAPE: 27.16, Validation SMAPE: 27.60
# Epoch 93/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.99, Validation MAE: 318.30
# Train RMSE: 336.32, Validation RMSE: 448.20
# Train SMAPE: 27.18, Validation SMAPE: 27.60
# Epoch 94/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.92, Validation MAE: 318.05
# Train RMSE: 336.70, Validation RMSE: 448.63
# Train SMAPE: 27.18, Validation SMAPE: 27.57
# Epoch 95/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.81, Validation MAE: 318.19
# Train RMSE: 336.86, Validation RMSE: 448.50
# Train SMAPE: 27.14, Validation SMAPE: 27.59
# Epoch 00161: reducing learning rate of group 0 to 1.5625e-06.
# Epoch 96/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.74, Validation MAE: 318.34
# Train RMSE: 336.91, Validation RMSE: 448.36
# Train SMAPE: 27.14, Validation SMAPE: 27.60
# Epoch 97/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 228.90, Validation MAE: 314.91
# Train RMSE: 335.33, Validation RMSE: 455.22
# Train SMAPE: 27.55, Validation SMAPE: 27.24
# Epoch 98/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.09, Validation MAE: 314.57
# Train RMSE: 336.65, Validation RMSE: 456.23
# Train SMAPE: 27.20, Validation SMAPE: 27.20
# Epoch 99/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.06, Validation MAE: 314.69
# Train RMSE: 337.20, Validation RMSE: 455.95
# Train SMAPE: 27.20, Validation SMAPE: 27.21
# Epoch 100/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.97, Validation MAE: 314.59
# Train RMSE: 336.88, Validation RMSE: 456.31
# Train SMAPE: 27.19, Validation SMAPE: 27.20
# Epoch 101/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.32, Validation MAE: 314.63
# Train RMSE: 337.28, Validation RMSE: 456.26
# Train SMAPE: 27.24, Validation SMAPE: 27.20
# Epoch 102/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.90, Validation MAE: 314.50
# Train RMSE: 337.04, Validation RMSE: 456.72
# Train SMAPE: 27.18, Validation SMAPE: 27.19
# Epoch 103/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.03, Validation MAE: 314.70
# Train RMSE: 337.40, Validation RMSE: 456.17
# Train SMAPE: 27.20, Validation SMAPE: 27.21
# Epoch 00169: reducing learning rate of group 0 to 7.8125e-07.
# Epoch 104/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.18, Validation MAE: 314.71
# Train RMSE: 336.93, Validation RMSE: 456.21
# Train SMAPE: 27.23, Validation SMAPE: 27.21
# Epoch 105/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 227.91, Validation MAE: 313.82
# Train RMSE: 335.45, Validation RMSE: 459.67
# Train SMAPE: 27.44, Validation SMAPE: 27.11
# Epoch 106/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.57, Validation MAE: 313.57
# Train RMSE: 336.63, Validation RMSE: 461.05
# Train SMAPE: 27.27, Validation SMAPE: 27.08
# Epoch 107/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.32, Validation MAE: 313.47
# Train RMSE: 336.97, Validation RMSE: 461.77
# Train SMAPE: 27.25, Validation SMAPE: 27.07
# Epoch 108/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 225.95, Validation MAE: 313.44
# Train RMSE: 337.07, Validation RMSE: 462.09
# Train SMAPE: 27.20, Validation SMAPE: 27.06
# Epoch 109/500 for dataset Detached_House_2
# Train Loss: 0.20, Validation Loss: 0.21
# Train MAE: 226.12, Validation MAE: 313.44
# Train RMSE: 337.39, Validation RMSE: 462.12
# Train SMAPE: 27.23, Validation SMAPE: 27.06
# Epoch 00175: reducing learning rate of group 0 to 3.9063e-07.
# Early stopping triggered after 110 epochs for dataset Detached_House_2.
